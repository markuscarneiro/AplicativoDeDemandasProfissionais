# %%
import sqlite3

# Caminho para o banco de dados SQLite
DB_PATH = 'db.sqlite3'

def listar_tabelas_e_registros():
    try:
        # Conectar ao banco de dados
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()

        # Listar todas as tabelas
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tabelas = cursor.fetchall()

        print("\nTabelas no banco de dados:")
        for tabela in tabelas:
            print(f"- {tabela[0]}")

        # Listar registros de cada tabela
        print("\nRegistros por tabela:")
        for tabela in tabelas:
            print(f"\nTabela: {tabela[0]}")
            cursor.execute(f"SELECT * FROM {tabela[0]};")
            registros = cursor.fetchall()

            if registros:
                for registro in registros:
                    print(registro)
            else:
                print("(Nenhum registro encontrado)")

        # Fechar conexão
        conn.close()

    except sqlite3.Error as e:
        print(f"Erro ao acessar o banco de dados: {e}")

if __name__ == "__main__":
    listar_tabelas_e_registros()
# Out:
# Tabelas no banco de dados:
# - django_migrations
# - sqlite_sequence
# - auth_group_permissions
# - auth_user_groups
# - auth_user_user_permissions
# - django_admin_log
# - django_content_type
# - auth_permission
# - auth_group
# - auth_user
# - django_session
# - demandas_demanda
# - demandas_tag
# - demandas_historicoalteracao
# - demandas_demanda_tags
# - demandas_comentario
# - demandas_anexoarquivo
#
# Registros por tabela:
#
# Tabela: django_migrations
# (1, 'contenttypes', '0001_initial', '2025-10-01 20:32:43.626101')
# (2, 'auth', '0001_initial', '2025-10-01 20:32:43.698784')
# (3, 'admin', '0001_initial', '2025-10-01 20:32:43.723891')
# (4, 'admin', '0002_logentry_remove_auto_add', '2025-10-01 20:32:43.738346')
# (5, 'admin', '0003_logentry_add_action_flag_choices', '2025-10-01 20:32:43.755018')
# (6, 'contenttypes', '0002_remove_content_type_name', '2025-10-01 20:32:43.770014')
# (7, 'auth', '0002_alter_permission_name_max_length', '2025-10-01 20:32:43.790707')
# (8, 'auth', '0003_alter_user_email_max_length', '2025-10-01 20:32:43.815384')
# (9, 'auth', '0004_alter_user_username_opts', '2025-10-01 20:32:43.815384')
# (10, 'auth', '0005_alter_user_last_login_null', '2025-10-01 20:32:43.831014')
# (11, 'auth', '0006_require_contenttypes_0002', '2025-10-01 20:32:43.850010')
# (12, 'auth', '0007_alter_validators_add_error_messages', '2025-10-01 20:32:43.853728')
# (13, 'auth', '0008_alter_user_username_max_length', '2025-10-01 20:32:43.888840')
# (14, 'auth', '0009_alter_user_last_name_max_length', '2025-10-01 20:32:43.904922')
# (15, 'auth', '0010_alter_group_name_max_length', '2025-10-01 20:32:43.921991')
# (16, 'auth', '0011_update_proxy_permissions', '2025-10-01 20:32:43.935962')
# (17, 'auth', '0012_alter_user_first_name_max_length', '2025-10-01 20:32:43.956984')
# (18, 'sessions', '0001_initial', '2025-10-01 20:32:43.973850')
# (19, 'demandas', '0001_initial', '2025-10-01 20:54:37.310536')
#
# Tabela: sqlite_sequence
# ('django_migrations', 19)
# ('django_admin_log', 0)
# ('django_content_type', 11)
# ('auth_permission', 44)
# ('auth_group', 0)
# ('auth_user', 5)
# ('demandas_demanda', 24)
# ('demandas_historicoalteracao', 30)
# ('demandas_anexoarquivo', 2)
# ('demandas_comentario', 3)
#
# Tabela: auth_group_permissions
# (Nenhum registro encontrado)
#
# Tabela: auth_user_groups
# (Nenhum registro encontrado)
#
# Tabela: auth_user_user_permissions
# (Nenhum registro encontrado)
#
# Tabela: django_admin_log
# (Nenhum registro encontrado)
#
# Tabela: django_content_type
# (1, 'admin', 'logentry')
# (2, 'auth', 'permission')
# (3, 'auth', 'group')
# (4, 'auth', 'user')
# (5, 'contenttypes', 'contenttype')
# (6, 'sessions', 'session')
# (7, 'demandas', 'tag')
# (8, 'demandas', 'demanda')
# (9, 'demandas', 'historicoalteracao')
# (10, 'demandas', 'anexoarquivo')
# (11, 'demandas', 'comentario')
#
# Tabela: auth_permission
# (1, 1, 'add_logentry', 'Can add log entry')
# (2, 1, 'change_logentry', 'Can change log entry')
# (3, 1, 'delete_logentry', 'Can delete log entry')
# (4, 1, 'view_logentry', 'Can view log entry')
# (5, 2, 'add_permission', 'Can add permission')
# (6, 2, 'change_permission', 'Can change permission')
# (7, 2, 'delete_permission', 'Can delete permission')
# (8, 2, 'view_permission', 'Can view permission')
# (9, 3, 'add_group', 'Can add group')
# (10, 3, 'change_group', 'Can change group')
# (11, 3, 'delete_group', 'Can delete group')
# (12, 3, 'view_group', 'Can view group')
# (13, 4, 'add_user', 'Can add user')
# (14, 4, 'change_user', 'Can change user')
# (15, 4, 'delete_user', 'Can delete user')
# (16, 4, 'view_user', 'Can view user')
# (17, 5, 'add_contenttype', 'Can add content type')
# (18, 5, 'change_contenttype', 'Can change content type')
# (19, 5, 'delete_contenttype', 'Can delete content type')
# (20, 5, 'view_contenttype', 'Can view content type')
# (21, 6, 'add_session', 'Can add session')
# (22, 6, 'change_session', 'Can change session')
# (23, 6, 'delete_session', 'Can delete session')
# (24, 6, 'view_session', 'Can view session')
# (25, 7, 'add_tag', 'Can add Tag')
# (26, 7, 'change_tag', 'Can change Tag')
# (27, 7, 'delete_tag', 'Can delete Tag')
# (28, 7, 'view_tag', 'Can view Tag')
# (29, 8, 'add_demanda', 'Can add Demanda')
# (30, 8, 'change_demanda', 'Can change Demanda')
# (31, 8, 'delete_demanda', 'Can delete Demanda')
# (32, 8, 'view_demanda', 'Can view Demanda')
# (33, 9, 'add_historicoalteracao', 'Can add Histórico de Alteração')
# (34, 9, 'change_historicoalteracao', 'Can change Histórico de Alteração')
# (35, 9, 'delete_historicoalteracao', 'Can delete Histórico de Alteração')
# (36, 9, 'view_historicoalteracao', 'Can view Histórico de Alteração')
# (37, 10, 'add_anexoarquivo', 'Can add Anexo')
# (38, 10, 'change_anexoarquivo', 'Can change Anexo')
# (39, 10, 'delete_anexoarquivo', 'Can delete Anexo')
# (40, 10, 'view_anexoarquivo', 'Can view Anexo')
# (41, 11, 'add_comentario', 'Can add Comentário')
# (42, 11, 'change_comentario', 'Can change Comentário')
# (43, 11, 'delete_comentario', 'Can delete Comentário')
# (44, 11, 'view_comentario', 'Can view Comentário')
#
# Tabela: auth_group
# (Nenhum registro encontrado)
#
# Tabela: auth_user
# (1, 'pbkdf2_sha256$600000$p3COPWLIszYxx3D4DOuEZU$KTvPsCZH4kBUWoC+0koGp29fUG46jRtYjCJbGYnsJoE=', '2025-10-06 12:05:47.875089', 1, 'admin', '', 'markuscarneiro888@gmail.com', 1, 1, '2025-10-01 21:11:42.954189', '')
#
# Tabela: django_session
# ('poy3ict1cepfpuc9situ6goj9u4xxae2', '.eJxVjEEOwiAQRe_C2pAyQAGX7j1DM8CMVA0kpV0Z765NutDtf-_9l5hwW8u0dVqmOYuzUOL0u0VMD6o7yHestyZTq-syR7kr8qBdXlum5-Vw_w4K9vKtHWgOA1sGZZVNjMaRJ48ByYAaiQabDLPXYMKAo8McGcgZZU0EDVq8P-BbN6I:1v447t:DrCznVJu6thsOg0zns5xOCdClMYAKh82gEqa--zm8UQ', '2025-10-15 21:12:41.821419')
# ('psyrpdg41e7fy105ahjph61idvbzmtj8', '.eJxVjEEOwiAQRe_C2pAyQAGX7j1DM8CMVA0kpV0Z765NutDtf-_9l5hwW8u0dVqmOYuzUOL0u0VMD6o7yHestyZTq-syR7kr8qBdXlum5-Vw_w4K9vKtHWgOA1sGZZVNjMaRJ48ByYAaiQabDLPXYMKAo8McGcgZZU0EDVq8P-BbN6I:1v48Cs:e_E4HMiLMjQHYeyTs2ZJYjXVNYfpE7h-D3XiOtVjUSs', '2025-10-16 01:34:06.443552')
# ('lkzzi8py2ulhv7fcgomfo0rsh7x7pa99', '.eJxVjEEOwiAQRe_C2pAyQAGX7j1DM8CMVA0kpV0Z765NutDtf-_9l5hwW8u0dVqmOYuzUOL0u0VMD6o7yHestyZTq-syR7kr8qBdXlum5-Vw_w4K9vKtHWgOA1sGZZVNjMaRJ48ByYAaiQabDLPXYMKAo8McGcgZZU0EDVq8P-BbN6I:1v4OGj:E1hCVND3vmNST8A0nXCj-hojfQiyv6OalznJJUspNa4', '2025-10-16 18:43:09.108188')
# ('q4n04eorb7mmvb3eojry4n9wolsdi4ax', '.eJxVjEEOwiAURO_C2pC2nx_ApXvP0PBhsFUDSWlXxrtrky50O--9eakxbOs0bg3LOCd1VqxOv5uE-EDZQbqHcqs61rIus-hd0Qdt-loTnpfD_TuYQpu-dW-8WAYJ-YxsyGaBRUpEjq1hB88ehro4AIieB-cyROLQd0m4c-r9AfMAOFU:1v4PfJ:mbC_Wm2KZv3AzNhMM8UuXw7Extvzvp1LhfNErDH1E0I', '2025-10-16 20:12:37.109294')
# ('ta22impa6aspadwuwt4c0phaq4o1065m', '.eJxVjEEOwiAQRe_C2pAyQAGX7j1DM8CMVA0kpV0Z765NutDtf-_9l5hwW8u0dVqmOYuzUOL0u0VMD6o7yHestyZTq-syR7kr8qBdXlum5-Vw_w4K9vKtHWgOA1sGZZVNjMaRJ48ByYAaiQabDLPXYMKAo8McGcgZZU0EDVq8P-BbN6I:1v4QpK:k_iWLAXsXsQN9RHGmH7gVzHXVzcJa_ri9H8OB9aQ79U', '2025-10-16 21:27:02.568891')
# ('zzw1s5c80007zdej85i0kd2b28k7ia0q', '.eJxVjEEOwiAQRe_C2pAyQAGX7j1DM8CMVA0kpV0Z765NutDtf-_9l5hwW8u0dVqmOYuzUOL0u0VMD6o7yHestyZTq-syR7kr8qBdXlum5-Vw_w4K9vKtHWgOA1sGZZVNjMaRJ48ByYAaiQabDLPXYMKAo8McGcgZZU0EDVq8P-BbN6I:1v5jyN:bl08EaGU3WyFx7Vglg6ZCuULENk6O0Ehb2g0sRmkZBM', '2025-10-20 12:05:47.875089')
#
# Tabela: demandas_demanda
# (1, 'DEM-2025-001', 'Encontrar obra no G2M', 'Falar com Ramon para identificar qual é o campo em que é possível consultar pelo código da obra no PROJ', 'Talise', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'andamento', 'alta', 4, 'N/A', 3, 0, '2025-10-01 21:48:18.583195', '2025-10-01 21:49:00.237391', 1)
# (2, 'DEM-2025-002', 'Gerar amostras aleatórias', 'Gerar amostra aleatória no SAP para AL e RS', 'Talise', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'andamento', 'alta', 4, 'N/A', 3, 0, '2025-10-01 22:21:31.120958', '2025-10-01 22:22:36.065787', 1)
# (3, 'DEM-2025-003', 'Atualizar as tabelas que alimentam os BIs', 'Atualizar as tabelas que alimentam os BIs. Importante atentar para as tabelas e consultas que o PG gerou', 'Talise', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'andamento', 'critica', 4, 'N/A', 8, 0, '2025-10-01 22:25:11.921400', '2025-10-01 22:25:11.921400', 1)
# (4, 'DEM-2025-004', 'Rodar consulta de PG com o teste das modificações', 'Rodar consulta de PG com o teste das modificações nos ativos. É aquele caso da visão diária', 'Talise', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'andamento', 'critica', 5, '', 8, 0, '2025-10-01 22:27:23.564349', '2025-10-01 22:27:23.564349', 1)
# (5, 'DEM-2025-005', 'Salvar gravações PROGEO', 'Salvar as gravações e as transcrições das reuniões com a PROGEO', 'Markus', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', '2025-10-03', 'concluida', 'baixa', 3, '', 4, 3, '2025-10-01 22:30:07.651805', '2025-10-03 21:47:28.937480', 1)
# (6, 'DEM-2025-006', 'Procurar consultas dos indicadores de auditoria continua do PG no sharepoint', 'Procurar consultas dos indicadores de auditoria continua do PG no sharepoint', 'Markus', 'Markus', 'Auditoria Contínua', '2025-10-01', '2025-10-03', None, 'pendente', 'media', 3, '', 2, 0, '2025-10-01 22:31:58.434659', '2025-10-01 22:31:58.434659', 1)
# (7, 'DEM-2025-007', 'Gestão de acessos G2M', 'Analisar e-mail de thiago abrantes com a resposta dos pontos de auditoria de acesso de banco de dados', 'Markus', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'pendente', 'alta', 3, '', 4, 0, '2025-10-02 01:36:23.503189', '2025-10-02 01:36:23.503245', 1)
# (8, 'DEM-2025-008', 'Duplicidades de Planos de Ação', 'Verificar problema na duplicidade dos planos de ação no sispauba', 'Markus', 'Markus', 'Sispauba', '2025-10-01', '2025-10-03', None, 'pendente', 'baixa', 1, '', 2, 0, '2025-10-02 01:51:47.274003', '2025-10-02 01:51:47.274534', 1)
# (9, 'DEM-2025-009', 'Cobrar pontos focais Planos de Ação', 'Enviar mensagens para os pontos focais dos planos de ação que foram cobrados e ainda não responderam os e-mails do dia 25.08.2025', 'Talise', 'Markus', 'Planos de Ação', '2025-10-01', '2025-10-03', None, 'andamento', 'media', 5, '', 2, 0, '2025-10-02 01:53:49.059456', '2025-10-02 01:53:49.059456', 1)
# (10, 'DEM-2025-010', 'Auditoria de Tarifas', 'Passar demanda do regulatório sobre a tarifa da EQTL MA para Diego', 'Talise', 'Markus', 'Auditoria de Tarifas', '2025-10-01', '2025-10-03', '2025-10-02', 'concluida', 'alta', 5, '', 1, 1, '2025-10-02 01:55:26.747746', '2025-10-02 19:20:43.535759', 1)
# (11, 'DEM-2025-011', 'Acessos PROJ', 'Ver questão do acesso do proj. Começar abrindo chamado.', 'Markus', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-10', None, 'pendente', 'critica', 5, '', 2, 0, '2025-10-02 01:57:17.272936', '2025-10-03 21:30:42.402402', 1)
# (12, 'DEM-2025-012', 'Obras desenergizadas', 'Levantar obras desenergizadas sem cadastro no G2M. Começar falando com Ramon e Sergio Henrique.', 'Markus', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'pendente', 'critica', 2, '', 4, 0, '2025-10-02 01:58:42.566574', '2025-10-03 21:47:50.784044', 1)
# (13, 'DEM-2025-013', 'Demandas reunião PROGEO 01.10.2025', '- cobrar o usuário de banco de dados que a progeo utiliza\r\n\r\n- cobrar o manual da empresa de referencia pra Sergio Henrique\r\n\r\n- baixar videos das gravações das reuniões com a PROGEO', 'Markus', 'Markus', 'G2M x AA', '2025-10-01', '2025-10-03', None, 'andamento', 'media', 5, '', 1, 0, '2025-10-02 02:00:44.054933', '2025-10-03 21:43:56.467243', 1)
# (14, 'DEM-2025-014', 'Concluir Indicador UBER', 'Demanda de Auditoria Contínua. Isso precisa ser fechado até o dia 20.10.2025', 'Guilherme', 'Markus', 'Metas Elegível', '2025-10-01', '2025-10-20', None, 'andamento', 'critica', 3, '', 16, 0, '2025-10-02 02:31:24.531939', '2025-10-03 21:46:29.612159', 1)
# (23, 'DEM-2025-015', 'Resumo tratativas semanal G2MxAA', 'Preparar resumo para enviar para Talise referente ao trabalho de G2M nesta última semana', 'Talise', 'Markus', 'G2M x AA', '2025-10-03', '2025-10-03', '2025-10-03', 'concluida', 'critica', 5, '', 1, 1, '2025-10-03 13:29:50.538624', '2025-10-03 18:22:24.089065', 1)
# (24, 'DEM-2025-016', 'Aditivo Snowflake', 'Acompanhar a demanda de criação do aditivo para liberação dos créditos do Snowflake', 'Markus', 'Markus', 'Auditoria Contínua', '2025-10-03', '2025-10-10', None, 'andamento', 'critica', 5, '', 1, 0, '2025-10-03 21:35:47.309098', '2025-10-03 21:35:47.309098', 1)
#
# Tabela: demandas_tag
# (Nenhum registro encontrado)
#
# Tabela: demandas_historicoalteracao
# (1, 'data_prazo', '0025-10-03', '2025-10-03', '2025-10-01 21:49:00.252494', 1, 1)
# (2, 'data_prazo', '0025-10-03', '2025-10-03', '2025-10-01 22:22:36.078601', 2, 1)
# (3, 'data_conclusao', '', '2025-10-02', '2025-10-02 19:20:43.554304', 10, 1)
# (4, 'status', 'Pendente', 'Concluída', '2025-10-02 19:20:43.554584', 10, 1)
# (5, 'tempo_realizado', '0.00', '1', '2025-10-02 19:20:43.581056', 10, 1)
# (21, 'data_conclusao', '', '2025-10-03', '2025-10-03 18:22:24.092842', 23, 1)
# (22, 'status', 'Em andamento', 'Concluída', '2025-10-03 18:22:24.107596', 23, 1)
# (23, 'tempo_realizado', '0.00', '1', '2025-10-03 18:22:24.107596', 23, 1)
# (24, 'data_prazo', '2025-10-03', '2025-10-10', '2025-10-03 21:30:42.416578', 11, 1)
# (25, 'prioridade', '3', '5', '2025-10-03 21:43:56.472912', 13, 1)
# (26, 'prioridade', '5', '3', '2025-10-03 21:46:29.622470', 14, 1)
# (27, 'data_conclusao', '', '2025-10-03', '2025-10-03 21:47:28.954381', 5, 1)
# (28, 'status', 'Em andamento', 'Concluída', '2025-10-03 21:47:28.954381', 5, 1)
# (29, 'tempo_realizado', '0.00', '3', '2025-10-03 21:47:28.969707', 5, 1)
# (30, 'prioridade', '5', '2', '2025-10-03 21:47:50.786635', 12, 1)
#
# Tabela: demandas_demanda_tags
# (Nenhum registro encontrado)
#
# Tabela: demandas_comentario
# (1, 'Chamados foram abertos em 03/10/2025', '2025-10-03 21:29:55.208154', 11, 1)
# (2, 'data de vencimento da demanda alterada para 10/10/2025 para acompanhar os chamados que foram abertos', '2025-10-03 21:31:23.588058', 11, 1)
# (3, 'Atualmente estamos aguardando um de acordo do Vanderlei para o valor da proposta. Ver anexo 1 com o e-mail enviado.', '2025-10-03 21:37:10.106259', 24, 1)
#
# Tabela: demandas_anexoarquivo
# (1, 'demandas/2025/10/01/CONTROLES_INTERNOS_-_G2M_PROGEO_-_PARTE_03.docx', 'CONTROLES INTERNOS - G2M (PROGEO) - PARTE 03.docx', 3870777, '2025-10-01 22:32:44.266756', 5, 1)
# (2, 'demandas/2025/10/03/anexo_aditivo.png', 'anexo aditivo.png', 78430, '2025-10-03 21:37:17.839759', 24, 1)
